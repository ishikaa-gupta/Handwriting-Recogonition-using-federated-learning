# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!unzip /content/drive/MyDrive/B.tech_Project/images.zip

# %%
import os
import os
import zipfile

zip_path = '/content/drive/MyDrive/B.tech_Project/images.zip'
destination_folder = '/content/training_dataset'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Extract the zip file to the destination folder
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(destination_folder)

# %%
import numpy as np
import random
import cv2
import os
from imutils import paths
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K

# %%
def load(paths, verbose=-1):
    '''expects images for each class in seperate dir, 
    e.g all digits in 0 class in the directory named 0 '''
    data = list()
    labels = list()
    # loop over the input images
    for (i, imgpath) in enumerate(paths):
        # load the image and extract the class labels
        im_gray = cv2.imread(imgpath, cv2.IMREAD_GRAYSCALE)
        image = np.array(im_gray).flatten()
        label = imgpath.split(os.path.sep)[-2]
        # scale the image to [0, 1] and add to list
        data.append(image/255)
        labels.append(label)
        # show an update every `verbose` images
        if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
            print("[INFO] processed {}/{}".format(i + 1, len(paths)))
    # return a tuple of the data and labels
    return data, labels

# %%
#declear path to your mnist data folder
img_path = '/content/training_dataset'

#get the path list using the path object
image_paths = list(paths.list_images(img_path))

#apply our function
image_list, label_list = load(image_paths, verbose=10000)

#binarize the labels
lb = LabelBinarizer()
label_list = lb.fit_transform(label_list)

#split data into training and test set
X_train, X_test, y_train, y_test = train_test_split(image_list, 
                                                    label_list, 
                                                    test_size=0.1, 
                                                    random_state=42)

# %%
def create_clients(image_list, label_list, num_clients=10, initial='clients'):
    ''' return: a dictionary with keys clients' names and value as 
                data shards - tuple of images and label lists.
        args: 
            image_list: a list of numpy arrays of training images
            label_list:a list of binarized labels for each image
            num_client: number of fedrated members (clients)
            initials: the clients'name prefix, e.g, clients_1 
            
    '''

    #create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]

    #randomize the data
    data = list(zip(image_list, label_list))
    random.shuffle(data)

    #shard data and place at each client
    size = len(data)//num_clients
    shards = [data[i:i + size] for i in range(0, size*num_clients, size)]

    #number of clients must equal number of shards
    assert(len(shards) == len(client_names))

    return {client_names[i] : shards[i] for i in range(len(client_names))}

# %%
#create clients
clients = create_clients(X_train, y_train, num_clients=10, initial='client')

# %%
def batch_data(data_shard, bs=32):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    return dataset.shuffle(len(label)).batch(bs)

# %%
#process and batch the training data for each client
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(data)
    
#process and batch the test set  
test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

# %%
class SimpleMLP:
    @staticmethod
    def build(shape, classes):
        model = Sequential()
        model.add(Dense(200, input_shape=(shape,)))
        model.add(Activation("relu"))
        model.add(Dense(200))
        model.add(Activation("relu"))
        model.add(Dense(classes))
        model.add(Activation("softmax"))
        return model

# %%
from tensorflow.keras import layers  
from tensorflow.keras import models
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import legacy

                    

lr = 0.01 
comms_round = 100
loss='categorical_crossentropy'
metrics = ['accuracy']
optimizer=legacy.Adam()

# %%
def weight_scalling_factor(clients_trn_data, client_name):
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name])[0][0].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final



def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(Y_test, logits)
    acc = accuracy_score(tf.argmax(logits, axis=1), tf.argmax(Y_test, axis=1))
    print('comm_round: {} | global_acc: {:.3%} | global_loss: {}'.format(comm_round, acc, loss))
    return acc, loss

# %%
#initialize global model
smlp_global = SimpleMLP()
global_model = smlp_global.build(784, 47)
        
#commence global training loop
for comm_round in range(comms_round):
            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:
        smlp_local = SimpleMLP()
        local_model = smlp_local.build(784, 47)
        local_model.compile(loss=loss, 
                      optimizer=optimizer, 
                      metrics=metrics)
        
        #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        
        #fit local model with client's data
        local_model.fit(clients_batched[client], epochs=1, verbose=0)
        
        #scale the model weights and add to list
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
        scaled_local_weight_list.append(scaled_weights)
        
        #clear session to free memory after each communication round
        K.clear_session()
        
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    #update global model 
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    for(X_test, Y_test) in test_batched:
        global_acc, global_loss = test_model(X_test, Y_test, global_model, comm_round)
# Out:
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 0 | global_acc: 21.429% | global_loss: 3.8376104831695557
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 1 | global_acc: 35.591% | global_loss: 3.765321969985962
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 2 | global_acc: 40.517% | global_loss: 3.723435640335083
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 3 | global_acc: 47.414% | global_loss: 3.686441659927368
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 4 | global_acc: 47.906% | global_loss: 3.654311418533325
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 5 | global_acc: 50.985% | global_loss: 3.6177687644958496
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 6 | global_acc: 52.340% | global_loss: 3.5756523609161377
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 7 | global_acc: 53.079% | global_loss: 3.5405328273773193
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 8 | global_acc: 55.049% | global_loss: 3.504154920578003
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 9 | global_acc: 59.483% | global_loss: 3.460331439971924
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 10 | global_acc: 61.330% | global_loss: 3.4336647987365723
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 11 | global_acc: 62.069% | global_loss: 3.402799367904663
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 12 | global_acc: 65.148% | global_loss: 3.377986192703247
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 13 | global_acc: 66.379% | global_loss: 3.361067771911621
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 14 | global_acc: 64.163% | global_loss: 3.345797300338745
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 15 | global_acc: 66.749% | global_loss: 3.3300116062164307
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 16 | global_acc: 67.118% | global_loss: 3.3134474754333496
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 17 | global_acc: 69.212% | global_loss: 3.291217088699341
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 18 | global_acc: 67.488% | global_loss: 3.2886102199554443
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 19 | global_acc: 71.305% | global_loss: 3.2676703929901123
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 20 | global_acc: 69.951% | global_loss: 3.2612075805664062
# 26/26 [==============================] - 0s 4ms/step
# comm_round: 21 | global_acc: 70.197% | global_loss: 3.2455861568450928
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 22 | global_acc: 72.044% | global_loss: 3.2383999824523926
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 23 | global_acc: 71.921% | global_loss: 3.229841470718384
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 24 | global_acc: 72.167% | global_loss: 3.2190163135528564
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 25 | global_acc: 72.414% | global_loss: 3.2127468585968018
# 26/26 [==============================] - 0s 4ms/step
# comm_round: 26 | global_acc: 74.138% | global_loss: 3.2023704051971436
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 27 | global_acc: 73.768% | global_loss: 3.20954966545105
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 28 | global_acc: 73.522% | global_loss: 3.191875696182251
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 29 | global_acc: 75.616% | global_loss: 3.1819419860839844
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 30 | global_acc: 76.355% | global_loss: 3.174422264099121
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 31 | global_acc: 75.985% | global_loss: 3.170656442642212
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 32 | global_acc: 75.985% | global_loss: 3.168329954147339
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 33 | global_acc: 75.246% | global_loss: 3.1695752143859863
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 34 | global_acc: 77.094% | global_loss: 3.151097536087036
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 35 | global_acc: 77.956% | global_loss: 3.1478018760681152
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 36 | global_acc: 78.079% | global_loss: 3.1441619396209717
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 37 | global_acc: 78.571% | global_loss: 3.145502805709839
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 38 | global_acc: 78.448% | global_loss: 3.131422281265259
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 39 | global_acc: 78.325% | global_loss: 3.1337664127349854
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 40 | global_acc: 78.818% | global_loss: 3.129284381866455
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 41 | global_acc: 78.571% | global_loss: 3.1313087940216064
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 42 | global_acc: 79.680% | global_loss: 3.11860728263855
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 43 | global_acc: 80.542% | global_loss: 3.1156766414642334
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 44 | global_acc: 78.202% | global_loss: 3.124248743057251
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 45 | global_acc: 79.433% | global_loss: 3.112788438796997
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 46 | global_acc: 78.571% | global_loss: 3.116304397583008
# 26/26 [==============================] - 0s 5ms/step
# comm_round: 47 | global_acc: 78.571% | global_loss: 3.112454652786255
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 48 | global_acc: 80.788% | global_loss: 3.107909917831421
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 49 | global_acc: 81.404% | global_loss: 3.098818063735962
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 50 | global_acc: 80.049% | global_loss: 3.0988874435424805
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 51 | global_acc: 80.911% | global_loss: 3.089824914932251
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 52 | global_acc: 82.020% | global_loss: 3.0886642932891846
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 53 | global_acc: 81.650% | global_loss: 3.0840964317321777
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 54 | global_acc: 81.650% | global_loss: 3.084362506866455
# 26/26 [==============================] - 0s 4ms/step
# comm_round: 55 | global_acc: 80.542% | global_loss: 3.0956180095672607
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 56 | global_acc: 81.773% | global_loss: 3.078197717666626
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 57 | global_acc: 81.773% | global_loss: 3.0802125930786133
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 58 | global_acc: 82.143% | global_loss: 3.0823585987091064
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 59 | global_acc: 82.389% | global_loss: 3.0781519412994385
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 60 | global_acc: 80.665% | global_loss: 3.087924003601074
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 61 | global_acc: 83.374% | global_loss: 3.072869300842285
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 62 | global_acc: 83.128% | global_loss: 3.0725739002227783
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 63 | global_acc: 83.867% | global_loss: 3.0687520503997803
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 64 | global_acc: 82.759% | global_loss: 3.077479839324951
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 65 | global_acc: 81.650% | global_loss: 3.07717227935791
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 66 | global_acc: 81.650% | global_loss: 3.0853400230407715
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 67 | global_acc: 82.143% | global_loss: 3.074227809906006
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 68 | global_acc: 83.621% | global_loss: 3.0650603771209717
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 69 | global_acc: 82.266% | global_loss: 3.0726985931396484
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 70 | global_acc: 84.113% | global_loss: 3.0603158473968506
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 71 | global_acc: 82.882% | global_loss: 3.067021131515503
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 72 | global_acc: 84.113% | global_loss: 3.0573058128356934
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 73 | global_acc: 83.128% | global_loss: 3.0617423057556152
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 74 | global_acc: 83.621% | global_loss: 3.060786485671997
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 75 | global_acc: 84.113% | global_loss: 3.061513900756836
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 76 | global_acc: 83.744% | global_loss: 3.059725046157837
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 77 | global_acc: 84.236% | global_loss: 3.0543248653411865
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 78 | global_acc: 84.483% | global_loss: 3.054361581802368
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 79 | global_acc: 83.867% | global_loss: 3.056957244873047
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 80 | global_acc: 83.251% | global_loss: 3.055556058883667
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 81 | global_acc: 83.990% | global_loss: 3.0533883571624756
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 82 | global_acc: 83.498% | global_loss: 3.0557684898376465
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 83 | global_acc: 82.020% | global_loss: 3.0691940784454346
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 84 | global_acc: 83.128% | global_loss: 3.0629467964172363
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 85 | global_acc: 83.990% | global_loss: 3.0488579273223877
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 86 | global_acc: 83.867% | global_loss: 3.0549185276031494
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 87 | global_acc: 84.236% | global_loss: 3.046421527862549
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 88 | global_acc: 83.867% | global_loss: 3.0488901138305664
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 89 | global_acc: 83.498% | global_loss: 3.049323320388794
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 90 | global_acc: 84.236% | global_loss: 3.0517890453338623
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 91 | global_acc: 83.128% | global_loss: 3.055826187133789
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 92 | global_acc: 84.236% | global_loss: 3.0455689430236816
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 93 | global_acc: 83.867% | global_loss: 3.0500359535217285
# 26/26 [==============================] - 0s 3ms/step
# comm_round: 94 | global_acc: 84.236% | global_loss: 3.04246187210083
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 95 | global_acc: 84.236% | global_loss: 3.0482444763183594
# 26/26 [==============================] - 0s 4ms/step
# comm_round: 96 | global_acc: 83.867% | global_loss: 3.05244779586792
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 97 | global_acc: 84.113% | global_loss: 3.0473411083221436
# 26/26 [==============================] - 0s 2ms/step
# comm_round: 98 | global_acc: 84.606% | global_loss: 3.043299436569214
# 26/26 [==============================] - 0s 4ms/step
# comm_round: 99 | global_acc: 84.729% | global_loss: 3.044126272201538

# %%
def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(Y_test, logits)
    acc = accuracy_score(tf.argmax(logits, axis=1), tf.argmax(Y_test, axis=1))
    print('comm_round: {} | global_acc: {:.3%} | global_loss: {}'.format(comm_round, acc, loss))
    return acc, loss
